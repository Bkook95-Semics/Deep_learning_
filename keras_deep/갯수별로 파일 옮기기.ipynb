# %%
import csv
import shutil

 
f = open('P완성본 개수.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
for (num, count) in rdr:
    shutil.copy("train_image\\P_"+str(num)+".bmp" , "train\\"+str(count)+"\\P_"+str(num)+".bmp")
    print('진행률 : ', num)
    
f.close() 
print('완료')
# Out:
# 진행률 :  1
# 진행률 :  2
# 진행률 :  3
# 진행률 :  4
# 진행률 :  5
# 진행률 :  6
# 진행률 :  7
# 진행률 :  8
# 진행률 :  9
# 진행률 :  10
# 진행률 :  11
# 진행률 :  12
# 진행률 :  13
# 진행률 :  14
# 진행률 :  15
# 진행률 :  16
# 진행률 :  17
# 진행률 :  18
# 진행률 :  19
# 진행률 :  20
# 진행률 :  21
# 진행률 :  22
# 진행률 :  23
# 진행률 :  24
# 진행률 :  25
# 진행률 :  26
# 진행률 :  27
# 진행률 :  28
# 진행률 :  29
# 진행률 :  30
# 진행률 :  31
# 진행률 :  32
# 진행률 :  33
# 진행률 :  34
# 진행률 :  35
# 진행률 :  36
# 진행률 :  37
# 진행률 :  38
# 진행률 :  39
# 진행률 :  40
# 진행률 :  41
# 진행률 :  42
# 진행률 :  43
# 진행률 :  44
# 진행률 :  45
# 진행률 :  46
# 진행률 :  47
# 진행률 :  48
# 진행률 :  49
# 진행률 :  50
# 진행률 :  51
# 진행률 :  52
# 진행률 :  53
# 진행률 :  54
# 진행률 :  55
# 진행률 :  56
# 진행률 :  57
# 진행률 :  58
# 진행률 :  59
# 진행률 :  60
# 진행률 :  61
# 진행률 :  62
# 진행률 :  63
# 진행률 :  64
# 진행률 :  65
# 진행률 :  66
# 진행률 :  67
# 진행률 :  68
# 진행률 :  69
# 진행률 :  70
# 진행률 :  71
# 진행률 :  72
# 진행률 :  73
# 진행률 :  74
# 진행률 :  75
# 진행률 :  76
# 진행률 :  77
# 진행률 :  78
# 진행률 :  79
# 진행률 :  80
# 진행률 :  81
# 진행률 :  82
# 진행률 :  83
# 진행률 :  84
# ...
